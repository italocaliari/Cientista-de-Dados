# %%
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/italocaliari/Cientista-de-Dados/refs/heads/main/apples_ts.csv'

# %%
dado = np.loadtxt(url,delimiter=',',usecols=np.arange(1,88,1))

# %%
dado.ndim
# Out:
# 2

# %%
dado.size
# Out:
# 522

# %%
dado.shape
# Out:
# (6, 87)

# %%
dado_trasposto = dado.T

# %%
datas = dado_trasposto[:,0]

# %%
precos = dado_trasposto[:,1:6]

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1,88,1)

# %%
plt.plot(datas,precos[:,0])

# %%
Moscow= precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Krasnodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
Moscow
# Out:
# array([ 79.72,  81.08,  79.68,  79.8 ,  80.63,  80.8 ,  80.28,  78.99,
#         76.77,  76.09,  76.36,  77.16,  77.5 ,  79.03,  80.28,  80.05,
#         78.11,  76.9 ,  77.68,  76.05,  75.53,  73.39,  78.36,  89.16,
#        105.43, 104.82, 101.15,  98.63,  99.96,  97.29,  98.64, 104.26,
#        102.63,  98.64,  97.17,  98.09, 103.07, 110.26, 110.84, 112.28,
#        111.1 , 110.06, 113.7 , 112.88, 102.08,  95.54,  91.33,  89.99,
#         91.44,  93.51,  93.6 ,  93.78,  98.91, 121.76, 129.6 , 127.9 ,
#        114.55, 101.88,  99.09, 103.35, 106.58, 108.  , 114.95, 121.17,
#        122.48, 127.58, 131.89, 129.36, 104.26,  93.45,  92.93,  96.15,
#         99.1 , 103.  , 103.31, 103.01, 107.37, 116.91, 125.29, 123.94,
#        113.03, 102.19,  97.83, 101.07, 103.44, 108.23, 110.28])

# %%
Moscow.shape
# Out:
# (87,)

# %%
Moscow_ano1 = Moscow[0:12]
Moscow_ano2 = Moscow[13:25]
Moscow_ano3 = Moscow[25:37]
Moscow_ano4 = Moscow[37:49]

# %%
plt.plot(np.arange(1,13,1),Moscow_ano1)
plt.plot(np.arange(1,13,1),Moscow_ano2)
plt.plot(np.arange(1,13,1),Moscow_ano3)
plt.plot(np.arange(1,13,1),Moscow_ano4)
plt.legend(['ano1','ano2','ano3','ano4'])

# %%
np.array_equal(Moscow_ano3,Moscow_ano4)
# Out:
# False

# %%
np.allclose(Moscow_ano3,Moscow_ano4,0.01)
# Out:
# False

# %%
plt.plot(datas,Kaliningrad)

# %%
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
sum(np.isnan(Kaliningrad))
# Out:
# np.int64(1)

# %%
(Kaliningrad[3]+Kaliningrad[5])/2
# Out:
# np.float64(49.17)

# %%
Kaliningrad[4] = np.mean([Kaliningrad[3],Kaliningrad[5]])

# %%
np.mean(Moscow)
# Out:
# np.float64(98.79781609195402)

# %%
np.mean(Kaliningrad)
# Out:
# np.float64(74.5506896551724)

# %%
plt.plot(datas,Moscow)

# %% [markdown]
# y=ax+b

# %%
x = datas

# %%
y = 2*x + 80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# np.float64(749.2329171225728)

# %%
y = 0.52*x + 80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# np.float64(110.48504740461489)

# %%
np.linalg.norm(Moscow-y)
# Out:
# np.float64(110.48504740461489)

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png]()

# %%
Y= Moscow
x= datas
n= np.size(Moscow)

# %%
(x**2).shape
# Out:
# (87,)

# %%
a = (n * np.sum(x * Y) - np.sum(x) * np.sum(Y)) / (n * np.sum(x**2) - (np.sum(x))**2)
print(f"O valor de 'a' é: {a}")
# Out:
# O valor de 'a' é: 0.43520212145512926

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
b = np.mean(Y) - a * np.mean(x)
print(f"O valor de 'b' é: {b}")
# Out:
# O valor de 'b' é: 79.64892274792834

# %%
y = a*x + b

# %%
np.linalg.norm(Moscow-y)
# Out:
# np.float64(101.7969539992751)

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)
plt.plot(41.5,41.5*a+b,'*r')
plt.plot(100,100*a+b,'*r')

# %%
np.random.randint(low=40,high=100,size=100)
# Out:
# array([54, 93, 55, 87, 63, 79, 83, 74, 51, 85, 86, 54, 85, 46, 62, 43, 53,
#        82, 84, 47, 41, 63, 88, 57, 98, 60, 99, 89, 76, 82, 88, 99, 93, 46,
#        55, 62, 87, 82, 77, 87, 92, 88, 58, 54, 53, 67, 96, 57, 94, 76, 91,
#        84, 68, 85, 50, 84, 87, 43, 76, 69, 59, 85, 95, 88, 86, 53, 84, 71,
#        92, 45, 64, 69, 58, 46, 93, 64, 67, 59, 56, 44, 77, 93, 84, 78, 67,
#        84, 81, 69, 66, 47, 50, 72, 86, 92, 77, 76, 84, 81, 58, 72])

# %%
coef_angulares = np.random.uniform(low=0.10,high=0.90,size=100)

# %%
norma2 = np.array([])
for i in range(100):
  norma2 = np.append(norma2,np.linalg.norm(Moscow-(coef_angulares[i]*x+b)))

# %%
norma2
# Out:
# array([117.6611641 , 121.54877788, 136.33951849, 223.06799097,
#        165.15954239, 155.59614646, 207.4575957 , 205.06930707,
#        150.65323363, 200.91346809, 148.02993788, 104.50857004,
#        144.02384794, 218.44014029, 111.13181862, 216.11047241,
#        103.69435191, 233.11108263, 133.01893638, 204.44243121,
#        198.62666444, 158.67529224, 106.56417695, 149.37052114,
#        126.80814596, 155.83236429, 117.66163578, 127.6796122 ,
#        102.59529061, 130.30989026, 163.86556726, 138.5310894 ,
#        231.18554629, 210.20690272, 206.65963766, 225.07620126,
#        125.43337535, 182.00746376, 102.98017456, 107.97277579,
#        205.12494346, 102.82169285, 131.34255667, 107.96226827,
#        180.31070488, 128.91166575, 143.38908863, 162.59177929,
#        182.70197326, 106.49888589, 125.2160423 , 127.14325594,
#        102.60943829, 102.33700226, 137.18163092, 202.52698944,
#        127.75992699, 130.8905092 , 121.94231646, 193.68025336,
#        102.25226212, 102.58515258, 101.80162119, 110.59722928,
#        126.93373178, 148.8568826 , 101.85188954, 213.17203178,
#        171.96143512, 113.39215095, 115.89291508, 128.67547279,
#        110.57263435, 212.31646385, 101.79888776, 102.46515218,
#        103.48258466, 109.82806256, 160.1361762 , 165.39561753,
#        163.36043461, 104.84891905, 136.27852197, 198.62137367,
#        136.54617706, 114.51037551, 145.47573158, 107.13068086,
#        105.2113794 , 227.83510844, 139.50605107, 147.27099854,
#        124.59733558, 110.21542204, 128.09052   , 111.44534612,
#        193.83240271, 111.56481362, 109.16698496, 179.77129506])

# %%
coef_angulares[1]
# Out:
# np.float64(0.575757694296359)

# %%
coef_angulares = np.random.uniform(low=0.10,high=0.90,size=100)

# %%
np.random.seed(16)
coef_angulares = np.random.uniform(low=0.10,high=0.90,size=100)

# %%
np.random.seed(16)
coef_angulares = np.random.uniform(low=0.10,high=0.90,size=100)
norma2 = np.array([])
for i in range(100):
  norma2 = np.append(norma2,np.linalg.norm(Moscow-(coef_angulares[i]*x+b)))
